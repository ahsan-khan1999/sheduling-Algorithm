# %%
if __name__ == "__main__":
    algo = int(input("Press 1 for FCFS : \nPress 2 for SJF : \nPress 3 For Periority Base Scheduling : "))
    
#     from timeit import Timer
    from time import time
    if(algo == 1):
        t0 = time()
        print(FCFS())
        t1 = time()
        print('FCFS Takes %f' %(t1-t0))
    elif(algo == 2):
        t0 = time()
        print(SJF())
        t1 = time()
        print('SJF Takes %f' %(t1-t0))
        
    elif(algo ==3):
        t0 = time()
        print(periority_scheduling())
        t1 = time()
        print('priority scheduling takes %f' %(t1-t0))
    else:
        print("Go to Hell!")
        
        
import timeit
print(timeit.timeit('''def SJF():
    queue = []
    total_wtime = 0
    n = int(input('Enter the total no of processes: '))
    for i in range(n):
        queue.append([])#append a list object to the list
        queue[i].append(input('Enter p_name: '))
        queue[i].append(int(input('Enter p_arrival: ')))
        total_wtime += queue[i][1]
        queue[i].append(int(input('Enter p_bust: ')))
    
    queue.sort(key = lambda queue:queue[2])
# for i in range(queue)

    print( 'ProcessName\tArrivalTime\tBurstTime')
    for i in range(n):
        print( queue[i][0],'\t\t',queue[i][1],'\t\t',queue[i][2])
    
    print( 'Total waiting time: ',total_wtime)
    print( 'Average waiting time: ',(total_wtime/n))''',number=1))



print(timeit.timeit('''def FCFS():
    import timeit
    
    queue = []
    total_wtime = 0
    n = int(input('Enter the total no of processes: '))
    for i in range(n):
        queue.append([])#append a list object to the list
        queue[i].append(input('Enter p_name: '))
        queue[i].append(int(input('Enter p_arrival: ')))
        total_wtime += queue[i][1]
        queue[i].append(int(input('Enter p_bust: ')))
    
    queue.sort(key = lambda queue:queue[1])
# for i in range(queue)

    print( 'ProcessName\tArrivalTime\tBurstTime')
    for i in range(n):
        print( queue[i][0],'\t\t',queue[i][1],'\t\t',queue[i][2])
    
    print( 'Total waiting time: ',total_wtime)
    print( 'Average waiting time: ',(total_wtime/n))
''',number=1))

print(timeit.timeit('''def periority_scheduling():
    queue = []
    total_wtime = 0
    n = int(input('Enter the total no of processes: '))
    for i in range(n):
        queue.append([])#append a list object to the list
        queue[i].append(input('Enter p_name: '))
        queue[i].append(int(input('Enter p_arrival: ')))
        total_wtime += queue[i][1]
        queue[i].append(int(input('Enter p_bust: ')))
        queue[i].append(int(input('Enter perioraity : ')))
    
    queue.sort(key = lambda queue:queue[3])
# for i in range(queue)

    print( 'ProcessName\tArrivalTime\tBurstTime')
    for i in range(n):
        print( queue[i][0],'\t\t',queue[i][1],'\t\t',queue[i][2])
    
    print( 'Total waiting time: ',total_wtime)
    print( 'Average waiting time: ',(total_wtime/n))''',number=1))

#     t0 = timeit
#     t = Timer("FCFS()", "from __main__ import FCFS")
#     print(t.timeit())
#     print(t.timeit())
#     print(FCFS())
#     print(SJF())
#     print(periority_scheduling())
# Out:
# Press 1 for FCFS :
# Press 2 for SJF :
# Press 3 For Periority Base Scheduling : 1
# Enter the total no of processes: 2
# Enter p_name: p1
# Enter p_arrival: 2
# Enter p_bust: 5
# Enter p_name: p2
# Enter p_arrival: 4
# Enter p_bust: 5
# ProcessName	ArrivalTime	BurstTime
# p1 		 2 		 5
# p2 		 4 		 5
# Total waiting time:  6
# Average waiting time:  3.0
# None
# FCFS Takes 15.586181
# 1.24100006360095e-06
# 1.3760000001639128e-06
# 8.360002539120615e-07

# %%
def FCFS():
    import timeit
    
    queue = []
    total_wtime = 0
    n = int(input('Enter the total no of processes: '))
    for i in range(n):
        queue.append([])#append a list object to the list
        queue[i].append(input('Enter p_name: '))
        queue[i].append(int(input('Enter p_arrival: ')))
        total_wtime += queue[i][1]
        queue[i].append(int(input('Enter p_bust: ')))
    
    queue.sort(key = lambda queue:queue[1])
# for i in range(queue)

    print( 'ProcessName\tArrivalTime\tBurstTime')
    for i in range(n):
        print( queue[i][0],'\t\t',queue[i][1],'\t\t',queue[i][2])
    
    print( 'Total waiting time: ',total_wtime)
    print( 'Average waiting time: ',(total_wtime/n))
#     queue[0]

# %%
def SJF():
    queue = []
    total_wtime = 0
    n = int(input('Enter the total no of processes: '))
    for i in range(n):
        queue.append([])#append a list object to the list
        queue[i].append(input('Enter p_name: '))
        queue[i].append(int(input('Enter p_arrival: ')))
        total_wtime += queue[i][1]
        queue[i].append(int(input('Enter p_bust: ')))
    
    queue.sort(key = lambda queue:queue[2])
# for i in range(queue)

    print( 'ProcessName\tArrivalTime\tBurstTime')
    for i in range(n):
        print( queue[i][0],'\t\t',queue[i][1],'\t\t',queue[i][2])
    
    print( 'Total waiting time: ',total_wtime)
    print( 'Average waiting time: ',(total_wtime/n))
#     queue[0]

# %%
def periority_scheduling():
    queue = []
    total_wtime = 0
    n = int(input('Enter the total no of processes: '))
    for i in range(n):
        queue.append([])#append a list object to the list
        queue[i].append(input('Enter p_name: '))
        queue[i].append(int(input('Enter p_arrival: ')))
        total_wtime += queue[i][1]
        queue[i].append(int(input('Enter p_bust: ')))
        queue[i].append(int(input('Enter perioraity : ')))
    
    queue.sort(key = lambda queue:queue[3])
# for i in range(queue)

    print( 'ProcessName\tArrivalTime\tBurstTime')
    for i in range(n):
        print( queue[i][0],'\t\t',queue[i][1],'\t\t',queue[i][2])
    
    print( 'Total waiting time: ',total_wtime)
    print( 'Average waiting time: ',(total_wtime/n))
#     queue[0]
